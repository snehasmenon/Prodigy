# %%
#importing librarys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics as stats
import seaborn as sns

# %%
#data set importing
df=pd.read_csv(r"C:\Users\Sneha Vijay\Downloads\virtual intern\prodigy\Covid19 India (Jan 20 - Mar 20).csv")

# %%
#fist five observation
df.head(5)
# Out:
#    Sno        Date State/UnionTerritory  ConfirmedIndianNational  \
# 0    1  30-01-2020               Kerala                        1
# 1    2  31-01-2020               Kerala                        1
# 2    3  01-02-2020               Kerala                        2
# 3    4  02-02-2020               Kerala                        3
# 4    5  03-02-2020               Kerala                        3
#
#    ConfirmedForeignNational  Cured  Deaths
# 0                         0      0       0
# 1                         0      0       0
# 2                         0      0       0
# 3                         0      0       0
# 4                         0      0       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       270 non-null    int64
#  1   Date                      270 non-null    object
#  2   State/UnionTerritory      270 non-null    object
#  3   ConfirmedIndianNational   270 non-null    int64
#  4   ConfirmedForeignNational  270 non-null    int64
#  5   Cured                     270 non-null    int64
#  6   Deaths                    270 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 14.9+ KB

# %%
#five summary
df.describe()
# Out:
#               Sno  ConfirmedIndianNational  ConfirmedForeignNational  \
# count  270.000000               270.000000                270.000000
# mean   135.500000                 5.551852                  1.329630
# std     78.086491                 8.339625                  3.587288
# min      1.000000                 0.000000                  0.000000
# 25%     68.250000                 1.000000                  0.000000
# 50%    135.500000                 3.000000                  0.000000
# 75%    202.750000                 6.000000                  0.000000
# max    270.000000                60.000000                 14.000000
#
#             Cured      Deaths
# count  270.000000  270.000000
# mean     0.603704    0.092593
# std      1.461522    0.290399
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      0.000000    0.000000
# max      9.000000    1.000000

# %%
#looking for null values
df.isnull().sum()
# Out:
# Sno                         0
# Date                        0
# State/UnionTerritory        0
# ConfirmedIndianNational     0
# ConfirmedForeignNational    0
# Cured                       0
# Deaths                      0
# dtype: int64

# %% [markdown]
# in this data set there is no null values

# %%
#missing value
sns.boxplot(df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# by looking at this graph some columns have postive outliers
#     1)  confirmed indian national
#     2)  confirmend foreign national
#     3)  curved
#     4)  deats

# %%
#for the distribution of data 
sns.barplot(df,x="Cured",y="Deaths")
plt.show()

# %%
df["Cured"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
#from the count plot we may assume that the overall data is in 0 th column

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\Sneha Vijay\AppData\Local\Temp\ipykernel_17704\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
plt.hist(x=df["ConfirmedIndianNational"])
plt.xlabel("ConfirmedIndianNational")
plt.ylabel("values")
plt.show()

# %% [markdown]
# #
# 1)confirmed indian national and confirmed foreign national have high negative correlation.
# 2)Cured and deaths have strong correlation

# %%
sns.pairplot(df)
plt.show()
